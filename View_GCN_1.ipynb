# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPTE/Deep-Geometry-Learning-on-Colab/blob/master/View_GCN_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive#colab 连接到托管代码执行程序
drive.mount('/content/drive')#挂载云端硬盘
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# data  __init__.py  model  README.md  tools  train.py

# %%
import os
os.chdir('/content/drive/My Drive/Untitled Folder/View-GCN/view-GCN')#切换工作目录

# %%
# !git clone https://github.com/weixmath/view-GCN.git

# %%
# !cd ./view-GCN/data  && unzip modelnet40v2png_ori4.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0260_018.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0168_018.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0166_005.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0141_007.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0182_004.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0125_012.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0082_010.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0280_017.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0050_009.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0237_006.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0168_002.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0242_002.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0273_009.png
#   inflating: modelnet40v2png_ori4/toilet/train/toilet_0078_016.png
# ...

# %%
# !pip install tensorboardX
# Out:
# ...
#      |████████████████████████████████| 204kB 2.8MB/s
# ...

# %%
# !python train.py -name view-gcn -num_models 0 -weight_decay 0.001 -num_views 20 -cnn_name resnet18
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# epoch 20, step 55: train_loss 0.012; train_acc 0.998
# epoch 20, step 56: train_loss 0.018; train_acc 0.995
# epoch 20, step 57: train_loss 0.011; train_acc 1.000
# epoch 20, step 58: train_loss 0.013; train_acc 0.998
# epoch 20, step 59: train_loss 0.016; train_acc 0.995
# epoch 20, step 60: train_loss 0.021; train_acc 0.995
# epoch 20, step 61: train_loss 0.016; train_acc 0.995
# epoch 20, step 62: train_loss 0.014; train_acc 1.000
# epoch 20, step 63: train_loss 0.017; train_acc 0.995
# epoch 20, step 64: train_loss 0.019; train_acc 0.993
# epoch 20, step 65: train_loss 0.015; train_acc 1.000
# epoch 20, step 66: train_loss 0.020; train_acc 0.998
# epoch 20, step 67: train_loss 0.010; train_acc 1.000
# epoch 20, step 68: train_loss 0.021; train_acc 0.995
# epoch 20, step 69: train_loss 0.022; train_acc 0.998
# epoch 20, step 70: train_loss 0.015; train_acc 0.998
# epoch 20, step 71: train_loss 0.017; train_acc 0.998
# ...
