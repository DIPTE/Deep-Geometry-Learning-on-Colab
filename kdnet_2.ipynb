# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPTE/Deep-Geometry-Learning-on-Colab/blob/master/kdnet_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls

# %% [markdown]
# ###备注：import 时出现如果出现类似下面的报错：
# ModuleNotFoundError: No module named ‘XXXX’
# 解决方案：将项目根目录添加到环境变量中:
# import sys
# cur = '/content/drive/My Drive/XXXX'
# sys.path.append(cur)

# %%
import os
os.chdir('/content/drive/My Drive')#切换工作目录

# %%
 # !rm -rf kdnet.pytorch

# %%
# !git clone https://github.com/fxia22/kdnet.pytorch.git

# %%
import os
os.chdir('/content/drive/My Drive/kdnet.pytorch/')#切换工作目录

# %%
# !bash download.sh

# %% [markdown]
# ###add
# --no-check-certificate

# %%
# !python train.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# batch: 5001, loss: 1.187682, correct 7/10
# batch: 5002, loss: 1.783341, correct 5/10
# batch: 5003, loss: 0.666425, correct 8/10
# batch: 5004, loss: 0.648768, correct 7/10
# batch: 5005, loss: 0.334180, correct 9/10
# batch: 5006, loss: 1.564507, correct 5/10
# batch: 5007, loss: 0.821783, correct 6/10
# batch: 5008, loss: 0.940817, correct 7/10
# batch: 5009, loss: 1.111657, correct 6/10
# batch: 5010, loss: 1.031285, correct 6/10
# batch: 5011, loss: 0.383146, correct 10/10
# batch: 5012, loss: 1.252021, correct 8/10
# batch: 5013, loss: 0.356995, correct 9/10
# batch: 5014, loss: 0.885854, correct 9/10
# batch: 5015, loss: 0.722012, correct 7/10
# batch: 5016, loss: 0.173205, correct 10/10
# batch: 5017, loss: 0.562948, correct 8/10
# batch: 5018, loss: 0.355522, correct 8/10
# batch: 5019, loss: 0.712443, correct 7/10
# batch: 5020, loss: 0.723607, correct 7/10
# batch: 5021, loss: 0.129403, correct 10/10
# batch: 5022, loss: 0.248358, correct 9/10
# ...

# %%
# !python test.py
# Out:
# {'Airplane': 0, 'Bag': 1, 'Cap': 2, 'Car': 3, 'Chair': 4, 'Earphone': 5, 'Guitar': 6, 'Knife': 7, 'Lamp': 8, 'Laptop': 9, 'Motorbike': 10, 'Mug': 11, 'Pistol': 12, 'Rocket': 13, 'Skateboard': 14, 'Table': 15}
# 16 1785
# 0/1785 , 1.000000
# 1/1785 , 1.000000
# 2/1785 , 1.000000
# 3/1785 , 1.000000
# 4/1785 , 1.000000
# 5/1785 , 1.000000
# 6/1785 , 0.857143
# 7/1785 , 0.875000
# 8/1785 , 0.888889
# 9/1785 , 0.900000
# 10/1785 , 0.909091
# 11/1785 , 0.916667
# 12/1785 , 0.923077
# 13/1785 , 0.928571
# 14/1785 , 0.933333
# 15/1785 , 0.937500
# 16/1785 , 0.941176
# 17/1785 , 0.944444
# 18/1785 , 0.947368
# 19/1785 , 0.950000
# 20/1785 , 0.904762
# 21/1785 , 0.909091
# 22/1785 , 0.913043
# 23/1785 , 0.916667
# 24/1785 , 0.920000
# 25/1785 , 0.923077
# 26/1785 , 0.925926
# 27/1785 , 0.928571
# 28/1785 , 0.931034
# 29/1785 , 0.933333
# 30/1785 , 0.935484
# 31/1785 , 0.937500
# 32/1785 , 0.939394
# 33/1785 , 0.941176
# 34/1785 , 0.942857
# 35/1785 , 0.944444
# 36/1785 , 0.945946
# ...
