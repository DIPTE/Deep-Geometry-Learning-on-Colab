# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPTE/Deep-Geometry-Learning-on-Colab/blob/master/SubdivNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# airplane.obj	 maps		   scripts     train_cls.py
# datagen_maps.py  README.md	   subdivnet   train_seg.py
# LICENSE		 requirements.txt  teaser.jpg

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !nvcc -V

# %%
import os
os.chdir('/content/drive/My Drive')#切换工作目录

# %%
# !git clone https://github.com/lzhengning/SubdivNet.git
# Out:
# Cloning into 'SubdivNet'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 124 (delta 56), reused 89 (delta 33), pack-reused 0
# Receiving objects: 100% (124/124), 712.63 KiB | 9.50 MiB/s, done.
# Resolving deltas: 100% (56/56), done.

# %%
import os
os.chdir('/content/drive/My Drive/SubdivNet')#切换工作目录

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.1MB 12.1MB/s
# ...
#      |████████████████████████████████| 133kB 49.8MB/s
# ...
#      |████████████████████████████████| 634kB 49.3MB/s
# ...
#   Created wheel for jittor: filename=jittor-1.2.3.55-cp37-none-any.whl size=1693684 sha256=e2b6d1ba71e88d4875314f8e29020ebc0e1eaf07558cdcf5f0d2086818805bf2
#   Stored in directory: /root/.cache/pip/wheels/72/25/39/00c71695ff247a1dc5101802794c63a9a1e5fec01cb38e8c77
# Successfully built jittor
# ...

# %%
# !sh scripts/shrec11-split10/get_data.sh
# !sh scripts/shrec11-split16/get_data.sh
# !sh scripts/cubes/get_data.sh
# !sh scripts/manifold40/get_data.sh
# !sh scripts/humanbody/get_data.sh
# !sh scripts/coseg-aliens/get_data.sh
# Out:
# --2021-07-03 21:00:22--  https://cloud.tsinghua.edu.cn/f/6e59181fd26d4a2dbad9/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.8.7
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.8.7|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/331a096a-93a8-49fa-8021-c9fec36090a2/SHREC11-MAPS-48-4-split10.zip [following]
# --2021-07-03 21:00:24--  https://cloud.tsinghua.edu.cn/seafhttp/files/331a096a-93a8-49fa-8021-c9fec36090a2/SHREC11-MAPS-48-4-split10.zip
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2172924462 (2.0G) [application/zip]
# Saving to: ‘SHREC11-MAPS-48-4-split10.zip’
#
# SHREC11-MAPS-48-4-s 100%[===================>]   2.02G  8.21MB/s    in 4m 9s
#
# 2021-07-03 21:04:33 (8.31 MB/s) - ‘SHREC11-MAPS-48-4-split10.zip’ saved [2172924462/2172924462]
#
# ...

# %%
# !sh scripts/shrec11-split10/get_pretrained.sh
# !sh scripts/shrec11-split16/get_pretrained.sh
# !sh scripts/cubes/get_pretrained.sh
# !sh scripts/manifold40/get_pretrained.sh
# !sh scripts/humanbody/get_pretrained.sh
# !sh scripts/coseg-aliens/get_pretrained.sh
# Out:
# --2021-07-03 23:26:08--  https://cloud.tsinghua.edu.cn/f/b1ac19339dd14c4d9631/?dl=1
# Resolving cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)... 101.6.8.7
# Connecting to cloud.tsinghua.edu.cn (cloud.tsinghua.edu.cn)|101.6.8.7|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cloud.tsinghua.edu.cn/seafhttp/files/e605cd5f-68fa-4e0c-a287-0b4537266140/shrec11-split10.pkl [following]
# --2021-07-03 23:26:09--  https://cloud.tsinghua.edu.cn/seafhttp/files/e605cd5f-68fa-4e0c-a287-0b4537266140/shrec11-split10.pkl
# Reusing existing connection to cloud.tsinghua.edu.cn:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1156336 (1.1M) [application/octet-stream]
# Saving to: ‘shrec11-split10.pkl’
#
# shrec11-split10.pkl 100%[===================>]   1.10M   594KB/s    in 1.9s
#
# 2021-07-03 23:26:11 (594 KB/s) - ‘shrec11-split10.pkl’ saved [1156336/1156336]
#
# ...

# %%
# !sh scripts/shrec11-split10/test.sh
# !sh scripts/shrec11-split16/test.sh
# !sh scripts/cubes/test.sh
# !sh scripts/manifold40/test.sh
# !sh scripts/humanbody/test.sh
# !sh scripts/coseg-aliens/test.sh
# Out:
# [i 0703 23:28:51.061375 20 lock.py:58] Create lock file:/root/.cache/jittor/default/jittor.lock
# [i 0703 23:28:51.073818 20 compiler.py:869] Jittor(1.2.3.55) src: /usr/local/lib/python3.7/dist-packages/jittor
# [i 0703 23:28:51.087680 20 compiler.py:870] g++ at /usr/bin/g++(7.5.0)
# [i 0703 23:28:51.087860 20 compiler.py:871] cache_path: /root/.cache/jittor/default/g++
# [i 0703 23:28:51.106178 20 __init__.py:286] Found nvcc(11.0.221) at /usr/local/cuda/bin/nvcc.
# [i 0703 23:28:51.143630 20 __init__.py:286] Found addr2line(2.30) at /usr/bin/addr2line.
# [i 0703 23:28:51.186981 20 compiler.py:958] py_include: -I/usr/include/python3.7m -I/usr/include/python3.7m
# [i 0703 23:28:51.221350 20 compiler.py:960] extension_suffix: .cpython-37m-x86_64-linux-gnu.so
# [i 0703 23:28:51.221552 20 compiler.py:32] Create cache dir: /root/.cache/jittor/default/g++/jit
# [i 0703 23:28:51.221736 20 compiler.py:32] Create cache dir: /root/.cache/jittor/default/g++/obj_files
# ...

# %%
# !sh scripts/manifold40/test.sh
# !sh scripts/shrec11-split10/test.sh
# Out:
# [i 0703 23:45:45.740948 04 compiler.py:869] Jittor(1.2.3.55) src: /usr/local/lib/python3.7/dist-packages/jittor
# [i 0703 23:45:45.752631 04 compiler.py:870] g++ at /usr/bin/g++(7.5.0)
# [i 0703 23:45:45.752716 04 compiler.py:871] cache_path: /root/.cache/jittor/default/g++
# [i 0703 23:45:45.763277 04 __init__.py:286] Found nvcc(11.0.221) at /usr/local/cuda/bin/nvcc.
# [i 0703 23:45:45.773713 04 __init__.py:286] Found addr2line(2.30) at /usr/bin/addr2line.
# [i 0703 23:45:45.813388 04 compiler.py:958] py_include: -I/usr/include/python3.7m -I/usr/include/python3.7m
# [i 0703 23:45:45.852245 04 compiler.py:960] extension_suffix: .cpython-37m-x86_64-linux-gnu.so
# [i 0703 23:45:46.064331 04 compiler.py:1093] OS type:ubuntu OS key:ubuntu
# [i 0703 23:45:46.065357 04 __init__.py:178] Total mem: 25.46GB, using 8 procs for compiling.
# [i 0703 23:45:46.372999 04 jit_compiler.cc:22] Load cc_path: /usr/bin/g++
# [i 0703 23:45:46.373758 04 init.cc:55] Found cuda archs: [70,]
# ...

# %%
# !sh scripts/shrec11-split10/train.sh
# Out:
# [i 0703 23:50:46.347791 68 compiler.py:869] Jittor(1.2.3.55) src: /usr/local/lib/python3.7/dist-packages/jittor
# [i 0703 23:50:46.359649 68 compiler.py:870] g++ at /usr/bin/g++(7.5.0)
# [i 0703 23:50:46.359784 68 compiler.py:871] cache_path: /root/.cache/jittor/default/g++
# [i 0703 23:50:46.369919 68 __init__.py:286] Found nvcc(11.0.221) at /usr/local/cuda/bin/nvcc.
# [i 0703 23:50:46.379842 68 __init__.py:286] Found addr2line(2.30) at /usr/bin/addr2line.
# [i 0703 23:50:46.417018 68 compiler.py:958] py_include: -I/usr/include/python3.7m -I/usr/include/python3.7m
# [i 0703 23:50:46.452441 68 compiler.py:960] extension_suffix: .cpython-37m-x86_64-linux-gnu.so
# [i 0703 23:50:46.642293 68 compiler.py:1093] OS type:ubuntu OS key:ubuntu
# [i 0703 23:50:46.643216 68 __init__.py:178] Total mem: 25.46GB, using 8 procs for compiling.
# [i 0703 23:50:46.927512 68 jit_compiler.cc:22] Load cc_path: /usr/bin/g++
# [i 0703 23:50:46.928269 68 init.cc:55] Found cuda archs: [70,]
# ...
