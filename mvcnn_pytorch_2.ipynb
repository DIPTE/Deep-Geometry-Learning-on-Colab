# %% [markdown]
# <a href="https://colab.research.google.com/github/DIPTE/Deep-Geometry-Learning-on-Colab/blob/master/mvcnn_pytorch_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# __init__.py		   models     shaded_images.tar.gz  train_mvcnn.py
# modelnet40_images_new_12x  README.md  tools

# %%
import os
os.chdir('/content/drive/My Drive')#切换工作目录

# %%
# !git clone https://github.com/jongchyisu/mvcnn_pytorch.git

# %%
import os
os.chdir('/content/drive/My Drive/mvcnn_pytorch/')#切换工作目录

# %%
import sys
cur = '/content/drive/My Drive/mvcnn_pytorch'
sys.path.append(cur)

# %%
# !wget http://supermoe.cs.umass.edu/shape_recog/shaded_images.tar.gz && tar -xzvf shaded_images.tar.gz

# %%
# !pip install tensorboardX

# %%
# !python train_mvcnn.py -name mvcnn -num_models 1000 -weight_decay 0.001 -num_views 12 -cnn_name vgg11
# Out:
# Downloading: "https://download.pytorch.org/models/vgg11-bbd30ac9.pth" to /root/.cache/torch/checkpoints/vgg11-bbd30ac9.pth
# 100% 507M/507M [00:03<00:00, 143MB/s]
# num_train_files: 99936
# num_val_files: 29616
# epoch 1, step 1: train_loss 3.767; train_acc 0.047
# epoch 1, step 2: train_loss 3.736; train_acc 0.016
# epoch 1, step 3: train_loss 3.598; train_acc 0.047
# epoch 1, step 4: train_loss 3.411; train_acc 0.141
# epoch 1, step 5: train_loss 3.540; train_acc 0.078
# epoch 1, step 6: train_loss 3.502; train_acc 0.094
# epoch 1, step 7: train_loss 3.210; train_acc 0.188
# epoch 1, step 8: train_loss 3.168; train_acc 0.219
# epoch 1, step 9: train_loss 3.155; train_acc 0.203
# epoch 1, step 10: train_loss 3.116; train_acc 0.266
# epoch 1, step 11: train_loss 3.066; train_acc 0.219
# epoch 1, step 12: train_loss 2.853; train_acc 0.250
# epoch 1, step 13: train_loss 2.980; train_acc 0.188
# epoch 1, step 14: train_loss 2.795; train_acc 0.281
# ...
